# %%
# Import the required modules
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
mu = 1

# %%
#van der pol differential equation
def vdp(state, t, mu):
    x = state[0]
    y = state[1]
    dxdt = y
    dydt = mu*(1-x**2)*y - x
    return [dxdt, dydt]

# %%
state = [1,2] #intial state
t = np.linspace(0, 100, 100000) #time vector

# %%
solution = odeint(vdp, state, t, args=(mu,)) #calculate solution

x = solution[:, 0]
y = solution[:, 1]

# %%
#plot solution as function of time
plt.plot(t, x, t, y)
plt.xlabel('t')
plt.legend(('x', 'y'))

# %%
#plot phase portrait
mu = 0.01
solution1 = odeint(vdp, state, t,args=(mu,))
mu = 0.1
solution2 = odeint(vdp, state, t,args=(mu,))
mu = 0.5
solution3 = odeint(vdp, state, t,args=(mu,))
mu = 1
solution4 = odeint(vdp, state, t,args=(mu,))
mu = 1.5
solution5 = odeint(vdp, state, t,args=(mu,))
mu = 2
solution6 = odeint(vdp, state, t,args=(mu,))
mu = 2.5
solution7 = odeint(vdp, state, t,args=(mu,))
mu = 3
solution8 = odeint(vdp, state, t,args=(mu,))
mu = 3.5
solution9 = odeint(vdp, state, t,args=(mu,))
mu = 4
solution10 = odeint(vdp, state, t,args=(mu,))

plt.figure()
plt.plot(solution1[:, 0],solution1[:, 1],label='mu=0.01')
plt.plot(solution2[:, 0],solution2[:, 1],label='mu=0.1')
plt.plot(solution3[:, 0],solution3[:, 1],label='mu=0.5')
plt.plot(solution4[:, 0],solution4[:, 1],label='mu=0.5')
plt.plot(solution5[:, 0],solution5[:, 1],label='mu=0.5')
plt.plot(solution6[:, 0],solution6[:, 1],label='mu=0.5')
plt.plot(solution7[:, 0],solution7[:, 1],label='mu=0.5')
plt.plot(solution8[:, 0],solution8[:, 1],label='mu=0.5')
plt.plot(solution9[:, 0],solution9[:, 1],label='mu=0.5')
plt.plot(solution10[:, 0],solution10[:, 1],label='mu=0.5')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-12,12)
plt.ylim(-7,7)
# Out:
# (-7.0, 7.0)
